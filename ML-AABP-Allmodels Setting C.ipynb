# %% [markdown]
# # Prediction of Bond Strength
# # Experiment Four: Train on the entire RBD-ACE2 OV Dataset and Evaluate the models on the entire RBD-ACE2 WT dataset

# %%
#Import packages
#Loading the dataset

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import pandas as pd
df = pd.read_excel("/Users/mateen/Downloads/Data 2/allbonding-RBD-ACE2-WT.xlsx")

# %%
#Declaring the Feature Variable
X = df.drop(['Unnamed: 5','Unnamed: 15','Atom1','Atom2','Unnamed: 25','BO', "Atom2.1","Atom1.1"], axis=1)

# %%
#Declaring the Target Variable (Bond Order)
y = df["BO"]

# %%
#X_test_copy = X_test.copy()

# %%
#X_test_copy

# %%
#Data Preprocessing (Label Encoding)
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()


X['bond'] = label_encoder.fit_transform(X['bond'])
X['Ele1'] = label_encoder.fit_transform(X['Ele1'])
X['Ele2'] = label_encoder.fit_transform(X['Ele2'])
X['PDBele1'] = label_encoder.fit_transform(X['PDBele1'])
X['AA1'] = label_encoder.fit_transform(X['AA1'])
X['PDBele2'] = label_encoder.fit_transform(X['PDBele2'])
X['ChainN1'] = label_encoder.fit_transform(X['ChainN1'])
X['ChainN2'] = label_encoder.fit_transform(X['ChainN2'])
X['AA2'] = label_encoder.fit_transform(X['AA2'])

# %%
X
# Out:
#        bond      BL  Ele1      x1      y1      z1  PDBele1  AA1  SeqNo1  \
# 0         0  1.3773     0  29.071  48.100  32.949       10    8      34
# 1         0  1.3783     0  36.312  21.408  29.838       10   17     328
# 2         0  1.3794     0  22.200  42.065  20.204       10   17      69
# 3         0  1.3801     0  31.489  31.071  49.933       10   17     436
# 4         0  1.3818     0  29.978  25.452   9.957       10    8     345
# ...     ...     ...   ...     ...     ...     ...      ...  ...     ...
# 25351    16  2.0325     4  25.872  18.327  13.556       79    4     344
# 25352    16  2.0375     4  41.696  37.089  59.275       79    4     379
# 25353    16  2.0375     4  30.886  36.126  69.106       79    4     336
# 25354    16  2.0388     4  20.540  63.728  34.067       79    4     480
# 25355    16  2.0493     4  39.037  39.360  75.943       79    4     391
#
#        ChainN1  Ele2      x2      y2      z2  PDBele2  AA2  SeqNo2  ChainN2
# ...

# %%
y = df["BO"]

# %%
#Training the Decision Tree Regressor
regressor = DecisionTreeRegressor()
param_grid = {
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto', 'sqrt', 'log2'],
    'criterion': ['mse', 'mae']
}
grid_search = GridSearchCV(regressor, param_grid, cv=10, scoring='neg_mean_squared_error', n_jobs=-1)
grid_search.fit(X, y)
# Out:
# /usr/local/lib/python3.10/site-packages/sklearn/tree/_classes.py:306: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /usr/local/lib/python3.10/site-packages/sklearn/tree/_classes.py:306: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /usr/local/lib/python3.10/site-packages/sklearn/tree/_classes.py:306: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /usr/local/lib/python3.10/site-packages/sklearn/tree/_classes.py:306: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# ...

# %%
print("Best parameters:", grid_search.best_params_)
print("Lowest RMSE: ", (-grid_search.best_score_)**(1/2.0))
# Out:
# Best parameters: {'criterion': 'mse', 'max_depth': 20, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 10}
# Lowest RMSE:  0.008451587582200491

# %%
#Saving the best model
#best_params_dt = grid_search.best_params_
#best_estimator_dt = grid_search.best_estimator_
import pickle
#Loading the best model
#pickle.dump(best_estimator_dt, open('/Users/mateen/DT_wt_all.pkl', 'wb'))
pickled_model = pickle.load(open('/Users/mateen/DT_ov_all.pkl', 'rb'))
y_grid_dt = pickled_model.predict(X)
# Out:
# /Users/mateen/Bond_Project/lib/python3.10/site-packages/sklearn/utils/validation.py:757: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# /Users/mateen/Bond_Project/lib/python3.10/site-packages/sklearn/utils/validation.py:595: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /Users/mateen/Bond_Project/lib/python3.10/site-packages/sklearn/utils/validation.py:604: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):

# %%
#Evaluating the Decision Tree Model on the WT Dataset
true_mean = np.mean(y)
squared_error_num = np.sum(np.abs(y - y_grid_dt))
squared_error_den = np.sum(np.abs(y - true_mean))
rae_loss = squared_error_num / squared_error_den

mse = mean_squared_error(y,y_grid_dt)
mae = mean_absolute_error(y, y_grid_dt)
r2 = r2_score(y, y_grid_dt)
rmse = np.sqrt(mse)

print(f"Mean Squared Error: {mse}")
print(f"Mean Absolute Error: {mae}")
print(f"R-squared: {r2}")
print(f"RAE: {rae_loss}")
print(f"RMSE: {rmse}")

# %%
# Training the KNN Regressor
from sklearn.neighbors import KNeighborsRegressor
param_grid = {
    'n_neighbors': [3, 5, 7, 9, 11],  
    'weights': ['uniform', 'distance'],  
    'p': [1, 2],  
}

# Initialize the KNN regressor
knn = KNeighborsRegressor()

# Create a GridSearchCV object with cross-validation (e.g., 5-fold)
grid_search_kn = GridSearchCV(estimator=knn, param_grid=param_grid, cv=10, scoring='neg_mean_squared_error', n_jobs=-1)

# Fit the grid search to your training data
grid_search_kn.fit(X, y)

# Get the best hyperparameters and the best estimator
best_params_kn = grid_search_kn.best_params_
best_estimator_kn = grid_search_kn.best_estimator_

# Use the best estimator to make predictions on the test set

pickle.dump(best_estimator_kn, open('/Users/mateen/KN_wt_all.pkl', 'wb'))

y_grid_kn = best_estimator_kn.predict(X)

# %%
pickled_model = pickle.load(open('/Users/mateen/KN_ov_all.pkl', 'rb'))
y_grid_kn = pickled_model.predict(X)

# %%
#Evaluating the KNN Model on the WT Dataset
true_mean = np.mean(y)
squared_error_num = np.sum(np.abs(y - y_grid_kn))
squared_error_den = np.sum(np.abs(y - true_mean))
rae_loss = squared_error_num / squared_error_den

mse = mean_squared_error(y,y_grid_kn)
mae = mean_absolute_error(y, y_grid_kn)
r2 = r2_score(y, y_grid_kn)
rmse = np.sqrt(mse)

print(f"Mean Squared Error: {mse}")
print(f"Mean Absolute Error: {mae}")
print(f"R-squared: {r2}")
print(f"RAE: {rae_loss}")
print(f"RMSE: {rmse}")

# %%
#Training the Ridge Regressor
from sklearn.linear_model import Ridge
ridge = Ridge()
param_grid = {
    'alpha': [0.1, 1, 10],
    'solver': ['auto', 'svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga'],
}
grid_search = GridSearchCV(estimator=ridge, param_grid=param_grid, cv=10)
grid_search.fit(X, y)
best_params = grid_search.best_params_
best_model = grid_search.best_estimator_
pickle.dump(best_model, open('/Users/mateen/LR_WT_all.pkl', 'wb'))

# %%
best_model = pickle.load(open('/Users/mateen/LR_OV_all.pkl', 'rb'))
y_grid = best_model.predict(X)

# %%
#Evaluating the Ridge Model on the entire WT Dataset
true_mean = np.mean(y)
squared_error_num = np.sum(np.abs(y - y_grid))
squared_error_den = np.sum(np.abs(y - true_mean))
rae_loss = squared_error_num / squared_error_den

mse = mean_squared_error(y,y_grid)
mae = mean_absolute_error(y, y_grid)
r2 = r2_score(y, y_grid)
rmse = np.sqrt(mse)

print(f"Mean Squared Error: {mse}")
print(f"Mean Absolute Error: {mae}")
print(f"R-squared: {r2}")
print(f"RAE: {rae_loss}")
print(f"RMSE: {rmse}")

# %%
#Training the Lasso Regressor
from sklearn.linear_model import Lasso
lasso = Lasso()
param_grid = {
    'alpha': [0.1, 1, 10],
    'max_iter': [100, 500, 1000],
    'tol': [1e-3, 1e-4, 1e-5],
}
grid_search = GridSearchCV(estimator=lasso, param_grid=param_grid, cv=10)
grid_search.fit(X, y)

best_params = grid_search.best_params_
best_model = grid_search.best_estimator_
pickle.dump(best_model, open('/Users/mateen/LRlarso_wt_all.pkl', 'wb'))

# %%
best_model = pickle.load(open('/Users/mateen/LRlarso_OV_all.pkl', 'rb'))
y_grid = best_model.predict(X)

# %%
#Evaluating the Lasso Regression on the entire WT Dataset
true_mean = np.mean(y )
squared_error_num = np.sum(np.abs(y - y_grid))
squared_error_den = np.sum(np.abs(y - true_mean))
rae_loss = squared_error_num / squared_error_den

mse = mean_squared_error(y,y_grid)
mae = mean_absolute_error(y, y_grid)
r2 = r2_score(y, y_grid)
rmse = np.sqrt(mse)

print(f"Mean Squared Error: {mse}")
print(f"Mean Absolute Error: {mae}")
print(f"R-squared: {r2}")
print(f"RAE: {rae_loss}")
print(f"RMSE: {rmse}")

# %%
# Training the XGB Regression
from sklearn.model_selection import GridSearchCV
import xgboost as xg

params = { 'max_depth': [3,6,10],
           'learning_rate': [0.01, 0.05, 0.1],
           'n_estimators': [100, 500, 1000],
           'colsample_bytree': [0.3, 0.7]}
xgbr = xg.XGBRegressor(seed = 20)
clf = GridSearchCV(estimator=xgbr, 
                   param_grid=params, cv= 10,
                   scoring='neg_mean_squared_error', 
                   verbose=1)
clf.fit(X, y)
print("Best parameters:", clf.best_params_)
print("Lowest RMSE: ", (-clf.best_score_)**(1/2.0))

# Get the best hyperparameters and the best estimator
best_params_clf = clf.best_params_
best_estimator_clf = clf.best_estimator_

# Use the best estimator to make predictions on the test set

pickle.dump(best_estimator_clf, open('/Users/mateen/XG_wt_all.pkl', 'wb'))

#y_grid_XG = best_estimator_kn.predict(X)
# Out:
# Fitting 10 folds for each of 54 candidates, totalling 540 fits
# Best parameters: {'colsample_bytree': 0.7, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 500}
# Lowest RMSE:  0.06855925705859423

# %%
best_model = pickle.load(open('/Users/mateen/XG_ov_all.pkl', 'rb'))
y_grid = best_model.predict(X)

# %%
#Evaluating the XGB Regression on the entire WT Dataset
true_mean = np.mean(y)
squared_error_num = np.sum(np.abs(y - y_grid))
squared_error_den = np.sum(np.abs(y - true_mean))
rae_loss = squared_error_num / squared_error_den

mse = mean_squared_error(y,y_grid)
mae = mean_absolute_error(y, y_grid)
r2 = r2_score(y, y_grid)
rmse = np.sqrt(mse)

print(f"Mean Squared Error: {mse}")
print(f"Mean Absolute Error: {mae}")
print(f"R-squared: {r2}")
print(f"RAE: {rae_loss}")
print(f"RMSE: {rmse}")
